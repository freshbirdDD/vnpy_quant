# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
encodings = ['utf-8', 'gbk', 'gb2312', 'utf-8-sig']
df = None

for encoding in encodings:
    try:
        df = pd.read_csv("data/bar_data_demo.csv", encoding=encoding)
        print(f"使用编码: {encoding}")
        break
    except UnicodeDecodeError:
        continue
# Out:
# 使用编码: gbk

# %%
order = sorted(list(set(df['合约代码'].tolist())))

# %%
order
# Out:
# ['IF1005',
#  'IF1006',
#  'IF1007',
#  'IF1008',
#  'IF1009',
#  'IF1010',
#  'IF1011',
#  'IF1012',
#  'IF1101',
#  'IF1102',
#  'IF1103',
#  'IF1104',
#  'IF1105',
#  'IF1106',
#  'IF1107',
#  'IF1108',
#  'IF1109',
#  'IF1110',
#  'IF1111',
#  'IF1112',
#  'IF1201',
#  'IF1202',
#  'IF1203',
#  'IF1204',
#  'IF1205',
#  'IF1206',
#  'IF1207',
#  'IF1208',
#  'IF1209',
#  'IF1210',
#  'IF1211',
#  'IF1212',
#  'IF1301',
#  'IF1302',
#  'IF1303',
#  'IF1304',
#  'IF1305',
#  'IF1306',
#  'IF1307',
#  'IF1308',
#  'IF1309',
#  'IF1310',
#  'IF1311',
#  'IF1312',
#  'IF1401',
#  'IF1402',
#  'IF1403',
#  'IF1404',
#  'IF1405',
#  'IF1406',
#  'IF1407',
#  'IF1408',
#  'IF1409',
#  'IF1410',
#  'IF1411',
#  'IF1412',
#  'IF1501',
#  'IF1502',
#  'IF1503',
#  'IF1504',
#  'IF1505',
#  'IF1506',
#  'IF1507',
#  'IF1508',
#  'IF1509',
#  'IF1510',
#  'IF1511',
#  'IF1512',
#  'IF1601',
#  'IF1602',
#  'IF1603',
#  'IF1604',
#  'IF1605',
#  'IF1606',
#  'IF1607',
#  'IF1608',
#  'IF1609',
#  'IF1610',
#  'IF1611',
#  'IF1612',
#  'IF1701',
#  'IF1702',
#  'IF1703',
#  'IF1704',
#  'IF1705',
#  'IF1706',
#  'IF1707',
#  'IF1708',
#  'IF1709',
#  'IF1710',
#  'IF1711',
#  'IF1712',
#  'IF1801',
#  'IF1802',
#  'IF1803',
#  'IF1804',
#  'IF1805',
#  'IF1806',
#  'IF1807',
#  'IF1808',
#  'IF1809',
#  'IF1810',
#  'IF1811',
#  'IF1812',
#  'IF1901',
#  'IF1902',
#  'IF1903',
#  'IF1904',
#  'IF1905',
#  'IF1906',
#  'IF1907',
#  'IF1908',
#  'IF1909',
#  'IF1910',
#  'IF1911',
#  'IF1912',
#  'IF2001',
#  'IF2002',
#  'IF2003',
#  'IF2004',
#  'IF2005',
#  'IF2006',
#  'IF2007',
#  'IF2008',
#  'IF2009',
#  'IF2010',
#  'IF2011',
#  'IF2012',
#  'IF2101',
#  'IF2102',
#  'IF2103',
#  'IF2104',
#  'IF2105',
#  'IF2106',
#  'IF2107',
#  'IF2108',
#  'IF2109',
#  'IF2110',
#  'IF2111',
#  'IF2112',
#  'IF2201',
#  'IF2202',
#  'IF2203',
#  'IF2204',
#  'IF2205',
#  'IF2206',
#  'IF2207',
#  'IF2208',
#  'IF2209',
#  'IF2210',
#  'IF2211',
#  'IF2212',
#  'IF2301',
#  'IF2302',
#  'IF2303',
#  'IF2304',
#  'IF2305',
#  'IF2306',
#  'IF2307',
#  'IF2308',
#  'IF2309',
#  'IF2310',
#  'IF2311',
#  'IF2312',
#  'IF2401',
#  'IF2402',
#  'IF2403',
#  'IF2404',
#  'IF2405',
#  'IF2406',
#  'IF2407',
#  'IF2408',
#  'IF2409',
#  'IF2410',
#  'IF2412',
#  'IF2503',
#  'IF2506',
#  'IF2509',
#  'IF2512',
#  'IF2603']
