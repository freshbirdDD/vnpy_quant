# %%
import pandas as pd

# %%
path = "/Users/jinhongdou/Desktop/2024-01_IF2401.CFFEX.csv"

# %%
df = pd.read_csv(path)

# %%
df[:3]
# Out:
#   instrumentID exchange  name                 datetime  tradingDay updateTime  \
# 0       IF2401    CFFEX   NaN  2024-01-02 00:00:00.000    20240102   00:00:00
# 1       IF2401    CFFEX   NaN  2024-01-02 07:03:06.100    20240102   07:03:06
# 2       IF2401    CFFEX   NaN  2024-01-02 09:29:00.100    20240102   09:29:00
#
#    updateMillisec  lastPrice  lastVolume  volume  ...  askVolume2  askVolume3  \
# 0               0     3439.4           0       0  ...           0           0
# 1             100     3439.4           0       0  ...           0           0
# 2             100     3439.4           0     108  ...           3          20
#
#    askVolume4  askVolume5  currDelta  preDelta  preOpenInterest  localtime  \
# 0           0           0        NaN       NaN              NaN        NaN
# 1           0           0        NaN       NaN              NaN        NaN
# 2           1          14        NaN       NaN              NaN        NaN
#
#    sourceYear      sourceVersion
# ...

# %%
df.columns
# Out:
# Index(['instrumentID', 'exchange', 'name', 'datetime', 'tradingDay',
#        'updateTime', 'updateMillisec', 'lastPrice', 'lastVolume', 'volume',
#        'turnover', 'openInterest', 'averagePrice', 'openPrice', 'highestPrice',
#        'lowestPrice', 'preClosePrice', 'preSettlementPrice', 'settlementPrice',
#        'closePrice', 'upperLimitPrice', 'lowerLimitPrice', 'bidPrice1',
#        'bidPrice2', 'bidPrice3', 'bidPrice4', 'bidPrice5', 'askPrice1',
#        'askPrice2', 'askPrice3', 'askPrice4', 'askPrice5', 'bidVolume1',
#        'bidVolume2', 'bidVolume3', 'bidVolume4', 'bidVolume5', 'askVolume1',
#        'askVolume2', 'askVolume3', 'askVolume4', 'askVolume5', 'currDelta',
#        'preDelta', 'preOpenInterest', 'localtime', 'sourceYear',
#        'sourceVersion'],
#       dtype='object')
